# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

from IPython.display import set_matplotlib_formats
set_matplotlib_formats('svg')

# %% [markdown]
# Абрамов №844(а, в, д)

# %%
x = np.linspace(-10, 10, 41)
y = 3 * (x ** 2)

m = np.linspace(-10, 10, 41)
n = m ** 3 + 2 * (m ** 2) + m

k = np.linspace(-10, 10, 41)
l = np.sin(k)

# %%
plt.figure(figsize=(8, 8))
plt.plot(x, y, color='green', linestyle='-', label='$y = 3 * x^2$')
plt.plot(m, n, color='red', linestyle='-.', label='$n = m^3 + 2 * m^2 + m$')
plt.plot(k, l, color='blue', linestyle='--', label='$l = sin(k)$')

plt.xlabel('Axis X')
plt.ylabel('Axis Y')
plt.title('Graphs')
plt.legend(loc = 'lower right', ncol=1, fontsize=11)
plt.grid(True)
plt.ylim(-40, 60)

plt.show()

# %% [markdown]
# Абрамов №846 (б, г, е, з)

# %%
x = np.linspace(-5, 5, 101)
y = (x + 3) / (x - 2)

m = np.linspace(-5, 5, 101)
n = 3 - (2 / m) - 3 / (m**2)

k = np.linspace(-5, 5, 101)
l = 1 / (k**2 + 2 * k + 1)

p = np.linspace(-5, 5, 101)
t = x / (3 * p**2 + 2 * p + 1)
# Out:
# /home/ihor/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
#
# /home/ihor/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """
# /home/ihor/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: divide by zero encountered in true_divide

# %%
plt.figure(figsize=(8, 8))

plt.plot(x, y, color='orange', linestyle=':', label='$y = (x + 3) / (x - 2)$')
plt.plot(m, n, color='red', linestyle='-', label='$n = 3 - (2 / m) - 3 / (m^2)$')
plt.plot(k, l, color='blue', linestyle='--', label='$l = k^2 + 2 * k + 1$')

plt.xlabel('Axis X')
plt.ylabel('Axis Y')
plt.title('Graphs')
plt.legend(loc = 'upper right', ncol=1, fontsize=11)
plt.grid(True)
plt.ylim(-50, 60)

plt.show()

# %% [markdown]
# Абрамов №847 (a, д)

# %%
t = np.linspace(0, 2 * np.pi, 61)
r = 2
x = r * np.cos(t)
y = r * np.sin(t)

# %%
plt.figure(figsize=(6, 6))
plt.title('Graph\n$x = r * cos(t)$, $y = r * sin(t)$, $t \in [0, 2*\pi]$')

ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

plt.plot(x, y)

plt.grid(True)
plt.ylim(-4, 4)
plt.xlim(-4, 4)

plt.show()

# %%
t = np.linspace(0, 2 * np.pi, 101)
a = 2
b = 6
x = (a + b) * np.cos(t) - a * np.cos((a + b) * (t / a))
y = (a + b) * np.sin(t) - a * np.sin((a + b) * (t / a))

# %%
plt.figure(figsize=(6, 6))
plt.title('Graph\n$x = (a + b) * cos(t) - a * cos((a + b) * (t / a))$\n'
            '$y = (a + b) * sin(t) - a * sin((a + b) * (t / a))$\n'
            '$b / a$ ціле число, $t \in [0, 2*\pi]$')

ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

plt.plot(x, y)

plt.grid(True)
#plt.ylim(-4, 4)
#plt.xlim(-4, 4)



plt.show()
